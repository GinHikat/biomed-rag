# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import ast

import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from module.data_processing.ctd import *
from module.data_processing.bc5cdr import *

# %%
ctd = CTD()
bc5cdr = BC5CDR()

# %%
# df = ctd.process_ctd('train')

# df = pd.concat([df, ctd.process_ctd('dev'), ctd.process_ctd('test')], axis = 0).reset_index(drop = True)

# df

# %%
# df['relationships'].iloc[0]

# %%
# df['mentions'].iloc[0]

# %%
# lookup_table = ctd.create_lookup_table(df)

# lookup_table
